# %%
conda update pycaret
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\flo-6\Anaconda
#
#   added / updated specs:
#     - pycaret
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> pkgs/main::ca-certificates-2023.01.10-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/win-64::certifi-2022.12.7-py310haa95532_0
#   conda              conda-forge::conda-23.3.1-py310h5588d~ --> pkgs/main::conda-23.3.1-py310haa95532_0
#
#
#
# Downloading and Extracting Packages
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge scikit-plot
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\flo-6\Anaconda
#
#   added / updated specs:
#     - scikit-plot
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-23.3.1               |  py310h5588dad_0         947 KB  conda-forge
#     scikit-plot-0.3.7          |             py_1          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         972 KB
#
# The following NEW packages will be INSTALLED:
#
#   scikit-plot        conda-forge/noarch::scikit-plot-0.3.7-py_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h5b45459_0
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   conda              pkgs/main::conda-23.3.1-py310haa95532~ --> conda-forge::conda-23.3.1-py310h5588dad_0
#
#
#
# Downloading and Extracting Packages
#
# conda-23.3.1         | 947 KB    |            |   0%
#
# scikit-plot-0.3.7    | 25 KB     |            |   0%
# conda-23.3.1         | 947 KB    | 1          |   2%
#
# scikit-plot-0.3.7    | 25 KB     | ######4    |  65%
#
# scikit-plot-0.3.7    | 25 KB     | ########## | 100%
# conda-23.3.1         | 947 KB    | ########## | 100%
# conda-23.3.1         | 947 KB    | ########## | 100%
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update pycaret
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
pip show pycaret
# Out:
# Name: pycaretNote: you may need to restart the kernel to use updated packages.
#
# Version: 2.2.3
# Summary: PyCaret - An open source, low-code machine learning library in Python.
# Home-page: https://github.com/pycaret/pycaret
# Author: Moez Ali
# Author-email: moez.ali@queensu.ca
# License: MIT
# Location: c:\users\flo-6\anaconda\lib\site-packages
# Requires: catboost, cufflinks, gensim, imbalanced-learn, IPython, ipywidgets, joblib, kmodes, lightgbm, matplotlib, mlflow, mlxtend, nltk, numpy, pandas, pandas-profiling, plotly, pyLDAvis, pyod, scikit-learn, scikit-plot, seaborn, spacy, textblob, umap-learn, wordcloud, xgboost, yellowbrick
# Required-by:

# %%
conda install -c conda-forge pycaret
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\flo-6\Anaconda
#
#   added / updated specs:
#     - pycaret
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alembic-1.10.3             |     pyhd8ed1ab_0         145 KB  conda-forge
#     blinker-1.6                |     pyhd8ed1ab_0          18 KB  conda-forge
#     ca-certificates-2022.12.7  |       h5b45459_0         143 KB  conda-forge
#     catalogue-2.0.8            |  py310h5588dad_1          33 KB  conda-forge
#     catboost-1.0.4             |  py310h5588dad_1        57.8 MB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     chart-studio-1.1.0         |     pyh9f0ad1d_0          51 KB  conda-forge
#     colorlover-0.3.0           |             py_0          12 KB  conda-forge
#     configparser-5.3.0         |     pyhd8ed1ab_0          22 KB  conda-forge
#     confuse-2.0.1              |     pyhd8ed1ab_0          26 KB  conda-forge
#     cufflinks-py-0.17.3        |             py_0           4 KB  conda-forge
#     cymem-2.0.6                |  py310h8a704f9_3          34 KB  conda-forge
#     cython-blis-0.7.8          |  py310h2873277_0         5.6 MB  conda-forge
#     databricks-cli-0.17.6      |     pyhd8ed1ab_0          85 KB  conda-forge
#     dataclasses-0.8            |     pyhc8e2a94_3          10 KB  conda-forge
#     datefinder-0.7.3           |     pyhd8ed1ab_0          14 KB  conda-forge
#     docker-py-6.0.0            |     pyhd8ed1ab_0          97 KB  conda-forge
#     funcy-2.0                  |     pyhd8ed1ab_0          29 KB  conda-forge
#     gitdb-4.0.10               |     pyhd8ed1ab_0          50 KB  conda-forge
#     gitpython-3.1.31           |     pyhd8ed1ab_0         138 KB  conda-forge
#     htmlmin-0.1.12             |             py_1          21 KB  conda-forge
#     imagehash-4.3.1            |     pyhd8ed1ab_0         294 KB  conda-forge
#     importlib_resources-5.12.0 |     pyhd8ed1ab_0          30 KB  conda-forge
#     kmodes-0.12.2              |     pyhd8ed1ab_0          20 KB  conda-forge
#     langcodes-3.3.0            |     pyhd8ed1ab_0         156 KB  conda-forge
#     libprotobuf-3.20.3         |       h23ce68f_0         2.2 MB
#     lightgbm-3.3.2             |  py310h8a704f9_0         884 KB  conda-forge
#     mako-1.2.4                 |     pyhd8ed1ab_0          61 KB  conda-forge
#     missingno-0.4.2            |             py_1          12 KB  conda-forge
#     mlflow-1.26.1              |  py310h2c4b17d_0         6.5 MB  conda-forge
#     mlxtend-0.22.0             |     pyhd8ed1ab_0         1.2 MB  conda-forge
#     multimethod-1.4            |             py_0          10 KB  conda-forge
#     murmurhash-1.0.8           |  py310h8a704f9_0          25 KB  conda-forge
#     oauthlib-3.2.2             |     pyhd8ed1ab_0          90 KB  conda-forge
#     pandas-profiling-3.0.0     |     pyhd8ed1ab_0         165 KB  conda-forge
#     pathy-0.10.1               |     pyhd8ed1ab_0          42 KB  conda-forge
#     phik-0.12.2                |  py310hc088e81_0         711 KB  conda-forge
#     preshed-3.0.7              |  py310h8a704f9_0          83 KB  conda-forge
#     prometheus_flask_exporter-0.22.3|     pyhd8ed1ab_0          22 KB  conda-forge
#     protobuf-3.20.3            |  py310h5588dad_1         225 KB  conda-forge
#     pybind11-abi-4             |       hd8ed1ab_3          10 KB  conda-forge
#     pycaret-2.2.3              |     pyhd3deb0d_0         166 KB  conda-forge
#     pydantic-1.8.2             |  py310he2412df_2         1.6 MB  conda-forge
#     pyldavis-3.3.1             |     pyhd8ed1ab_0         114 KB  conda-forge
#     pynndescent-0.5.8          |     pyh1a96a4e_0          47 KB  conda-forge
#     pyod-1.0.9                 |     pyhd8ed1ab_0         107 KB  conda-forge
#     python-cufflinks-0.17.3    |             py_0          59 KB  conda-forge
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     pywin32-on-windows-0.1.0   |     pyh07e9846_2           5 KB  conda-forge
#     querystring_parser-1.2.4   |             py_0          10 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     seaborn-base-0.12.2        |     pyhd8ed1ab_0         226 KB  conda-forge
#     shellingham-1.5.1          |     pyhd8ed1ab_0          14 KB  conda-forge
#     smmap-3.0.5                |     pyh44b312d_0          22 KB  conda-forge
#     spacy-3.2.4                |  py310hc781a3c_0         8.9 MB  conda-forge
#     spacy-legacy-3.0.12        |     pyhd8ed1ab_0          28 KB  conda-forge
#     spacy-loggers-1.0.4        |     pyhd8ed1ab_0          15 KB  conda-forge
#     sqlparse-0.4.3             |     pyhd8ed1ab_0          35 KB  conda-forge
#     srsly-2.4.4                |  py310h8a704f9_0         511 KB  conda-forge
#     tangled-up-in-unicode-0.2.0|     pyhd8ed1ab_0         2.9 MB  conda-forge
#     textblob-0.15.3            |             py_0         595 KB  conda-forge
#     thinc-8.0.17               |  py310hc781a3c_0         971 KB  conda-forge
#     typer-0.4.2                |     pyhd8ed1ab_0          45 KB  conda-forge
#     umap-learn-0.5.3           |  py310h5588dad_0         133 KB  conda-forge
#     visions-0.7.1              |     pyhd8ed1ab_0          61 KB  conda-forge
#     waitress-2.1.2             |     pyhd8ed1ab_0          46 KB  conda-forge
#     wasabi-0.10.1              |     pyhd8ed1ab_1          25 KB  conda-forge
#     wordcloud-1.8.2.2          |  py310he2412df_0         188 KB  conda-forge
#     yellowbrick-1.5            |     pyhd8ed1ab_0         160 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        94.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   alembic            conda-forge/noarch::alembic-1.10.3-pyhd8ed1ab_0
#   blinker            conda-forge/noarch::blinker-1.6-pyhd8ed1ab_0
#   catalogue          conda-forge/win-64::catalogue-2.0.8-py310h5588dad_1
#   catboost           conda-forge/win-64::catboost-1.0.4-py310h5588dad_1
#   chart-studio       conda-forge/noarch::chart-studio-1.1.0-pyh9f0ad1d_0
#   colorlover         conda-forge/noarch::colorlover-0.3.0-py_0
#   configparser       conda-forge/noarch::configparser-5.3.0-pyhd8ed1ab_0
#   confuse            conda-forge/noarch::confuse-2.0.1-pyhd8ed1ab_0
#   cufflinks-py       conda-forge/noarch::cufflinks-py-0.17.3-py_0
#   cymem              conda-forge/win-64::cymem-2.0.6-py310h8a704f9_3
#   cython-blis        conda-forge/win-64::cython-blis-0.7.8-py310h2873277_0
#   databricks-cli     conda-forge/noarch::databricks-cli-0.17.6-pyhd8ed1ab_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   datefinder         conda-forge/noarch::datefinder-0.7.3-pyhd8ed1ab_0
#   docker-py          conda-forge/noarch::docker-py-6.0.0-pyhd8ed1ab_0
#   funcy              conda-forge/noarch::funcy-2.0-pyhd8ed1ab_0
#   gitdb              conda-forge/noarch::gitdb-4.0.10-pyhd8ed1ab_0
#   gitpython          conda-forge/noarch::gitpython-3.1.31-pyhd8ed1ab_0
#   htmlmin            conda-forge/noarch::htmlmin-0.1.12-py_1
#   imagehash          conda-forge/noarch::imagehash-4.3.1-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-5.12.0-pyhd8ed1ab_0
#   kmodes             conda-forge/noarch::kmodes-0.12.2-pyhd8ed1ab_0
#   langcodes          conda-forge/noarch::langcodes-3.3.0-pyhd8ed1ab_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.20.3-h23ce68f_0
#   lightgbm           conda-forge/win-64::lightgbm-3.3.2-py310h8a704f9_0
#   mako               conda-forge/noarch::mako-1.2.4-pyhd8ed1ab_0
#   missingno          conda-forge/noarch::missingno-0.4.2-py_1
#   mlflow             conda-forge/win-64::mlflow-1.26.1-py310h2c4b17d_0
#   mlxtend            conda-forge/noarch::mlxtend-0.22.0-pyhd8ed1ab_0
#   multimethod        conda-forge/noarch::multimethod-1.4-py_0
#   murmurhash         conda-forge/win-64::murmurhash-1.0.8-py310h8a704f9_0
#   oauthlib           conda-forge/noarch::oauthlib-3.2.2-pyhd8ed1ab_0
#   pandas-profiling   conda-forge/noarch::pandas-profiling-3.0.0-pyhd8ed1ab_0
#   pathy              conda-forge/noarch::pathy-0.10.1-pyhd8ed1ab_0
#   phik               conda-forge/win-64::phik-0.12.2-py310hc088e81_0
#   preshed            conda-forge/win-64::preshed-3.0.7-py310h8a704f9_0
#   prometheus_flask_~ conda-forge/noarch::prometheus_flask_exporter-0.22.3-pyhd8ed1ab_0
#   protobuf           conda-forge/win-64::protobuf-3.20.3-py310h5588dad_1
#   pybind11-abi       conda-forge/noarch::pybind11-abi-4-hd8ed1ab_3
#   pycaret            conda-forge/noarch::pycaret-2.2.3-pyhd3deb0d_0
#   pydantic           conda-forge/win-64::pydantic-1.8.2-py310he2412df_2
#   pyldavis           conda-forge/noarch::pyldavis-3.3.1-pyhd8ed1ab_0
#   pynndescent        conda-forge/noarch::pynndescent-0.5.8-pyh1a96a4e_0
#   pyod               conda-forge/noarch::pyod-1.0.9-pyhd8ed1ab_0
#   python-cufflinks   conda-forge/noarch::python-cufflinks-0.17.3-py_0
#   python_abi         conda-forge/win-64::python_abi-3.10-2_cp310
#   pywin32-on-windows conda-forge/noarch::pywin32-on-windows-0.1.0-pyh07e9846_2
#   querystring_parser conda-forge/noarch::querystring_parser-1.2.4-py_0
#   retrying           conda-forge/noarch::retrying-1.3.3-py_2
#   seaborn-base       conda-forge/noarch::seaborn-base-0.12.2-pyhd8ed1ab_0
#   shellingham        conda-forge/noarch::shellingham-1.5.1-pyhd8ed1ab_0
#   smmap              conda-forge/noarch::smmap-3.0.5-pyh44b312d_0
#   spacy              conda-forge/win-64::spacy-3.2.4-py310hc781a3c_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.12-pyhd8ed1ab_0
#   spacy-loggers      conda-forge/noarch::spacy-loggers-1.0.4-pyhd8ed1ab_0
#   sqlparse           conda-forge/noarch::sqlparse-0.4.3-pyhd8ed1ab_0
#   srsly              conda-forge/win-64::srsly-2.4.4-py310h8a704f9_0
#   tangled-up-in-uni~ conda-forge/noarch::tangled-up-in-unicode-0.2.0-pyhd8ed1ab_0
#   textblob           conda-forge/noarch::textblob-0.15.3-py_0
#   thinc              conda-forge/win-64::thinc-8.0.17-py310hc781a3c_0
#   typer              conda-forge/noarch::typer-0.4.2-pyhd8ed1ab_0
#   umap-learn         conda-forge/win-64::umap-learn-0.5.3-py310h5588dad_0
#   visions            conda-forge/noarch::visions-0.7.1-pyhd8ed1ab_0
#   waitress           conda-forge/noarch::waitress-2.1.2-pyhd8ed1ab_0
#   wasabi             conda-forge/noarch::wasabi-0.10.1-pyhd8ed1ab_1
#   wordcloud          conda-forge/win-64::wordcloud-1.8.2.2-py310he2412df_0
#   yellowbrick        conda-forge/noarch::yellowbrick-1.5-pyhd8ed1ab_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h5b45459_0
#   certifi            pkgs/main/win-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
#
# kmodes-0.12.2        | 20 KB     |            |   0%
#
# mako-1.2.4           | 61 KB     |            |   0%
#
#
# gitdb-4.0.10         | 50 KB     |            |   0%
#
#
#
# pydantic-1.8.2       | 1.6 MB    |            |   0%
#
#
#
#
# smmap-3.0.5          | 22 KB     |            |   0%
#
#
#
#
#
# tangled-up-in-unicod | 2.9 MB    |            |   0%
#
#
#
#
#
#
# catalogue-2.0.8      | 33 KB     |            |   0%
#
#
#
#
#
#
#
# pywin32-on-windows-0 | 5 KB      |            |   0%
#
#
#
#
#
#
#
#
# murmurhash-1.0.8     | 25 KB     |            |   0%
#
#
#
#
#
#
#
#
#
# textblob-0.15.3      | 595 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# retrying-1.3.3       | 11 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# docker-py-6.0.0      | 97 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pyldavis-3.3.1       | 114 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# colorlover-0.3.0     | 12 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-3.20.3      | 225 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.1        | 61 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# databricks-cli-0.17. | 85 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.4      | 10 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# gitdb-4.0.10         | 50 KB     | #########5 |  95%
#
#
#
#
#
# tangled-up-in-unicod | 2.9 MB    |            |   1%
#
#
#
#
# smmap-3.0.5          | 22 KB     | ########## | 100%
#
#
#
#
# smmap-3.0.5          | 22 KB     | ########## | 100%
# kmodes-0.12.2        | 20 KB     | #######9   |  79%
#
#
# gitdb-4.0.10         | 50 KB     | ########## | 100%
#
# mako-1.2.4           | 61 KB     | ########## | 100%
#
# mako-1.2.4           | 61 KB     | ########## | 100%
# kmodes-0.12.2        | 20 KB     | ########## | 100%
#
#
#
#
#
#
#
# pywin32-on-windows-0 | 5 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# textblob-0.15.3      | 595 KB    | 2          |   3%
#
#
#
#
#
#
#
#
# murmurhash-1.0.8     | 25 KB     | ######5    |  65%
#
#
#
# pydantic-1.8.2       | 1.6 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
# retrying-1.3.3       | 11 KB     | ########## | 100%
#
#
#
#
#
#
#
# pywin32-on-windows-0 | 5 KB      | ########## | 100%
#
#
#
# pydantic-1.8.2       | 1.6 MB    | #3         |  14%
#
#
#
#
#
#
#
#
# murmurhash-1.0.8     | 25 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# retrying-1.3.3       | 11 KB     | ########## | 100%
#
#
#
#
#
#
#
#
# murmurhash-1.0.8     | 25 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# docker-py-6.0.0      | 97 KB     | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# pyldavis-3.3.1       | 114 KB    | #4         |  14%
#
#
#
# pydantic-1.8.2       | 1.6 MB    | ###6       |  36%
#
#
#
#
#
#
# catalogue-2.0.8      | 33 KB     | ####8      |  49%
#
#
#
#
#
#
#
#
#
# textblob-0.15.3      | 595 KB    | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-3.20.3      | 225 KB    | 7          |   7%
#
#
#
# pydantic-1.8.2       | 1.6 MB    | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# pyldavis-3.3.1       | 114 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyldavis-3.3.1       | 114 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# colorlover-0.3.0     | 12 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# databricks-cli-0.17. | 85 KB     | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
# docker-py-6.0.0      | 97 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# docker-py-6.0.0      | 97 KB     | ########## | 100%
#
#
#
#
#
#
# catalogue-2.0.8      | 33 KB     | ########## | 100%
#
#
#
#
#
#
# catalogue-2.0.8      | 33 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.1        | 61 KB     | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.4      | 10 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-3.20.3      | 225 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# protobuf-3.20.3      | 225 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# textblob-0.15.3      | 595 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# textblob-0.15.3      | 595 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# colorlover-0.3.0     | 12 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# databricks-cli-0.17. | 85 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# databricks-cli-0.17. | 85 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# imagehash-4.3.1      | 294 KB    | ########## | 100%
#
#
#
# pydantic-1.8.2       | 1.6 MB    | ########## | 100%
#
#
#
#
#
# tangled-up-in-unicod | 2.9 MB    | ########## | 100%
#
#
#
#
#
# tangled-up-in-unicod | 2.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multimethod-1.4      | 10 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.1        | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# visions-0.7.1        | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
